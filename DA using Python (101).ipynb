# %%
import pandas as pd

# %%
url="http://nrvis.com/data/mldata/autos_imports-85.csv"

# %%
df= pd.read_csv(url)

# %%
df.head(5)
# Out:
#         %symboling normalized-losses make fuel-type   aspiration num-of-doors  \
# 3 ?    alfa-romero               gas  std       two  convertible          rwd
#   ?    alfa-romero               gas  std       two  convertible          rwd
# 1 ?    alfa-romero               gas  std       two    hatchback          rwd
# 2 164         audi               gas  std      four        sedan          fwd
#   164         audi               gas  std      four        sedan          4wd
#
#       body-style  drive-wheels  wheel-base  length  ...  num-of-cylinders  \
# 3 ?        front          88.6       168.8    64.1  ...               130
#   ?        front          88.6       168.8    64.1  ...               130
# 1 ?        front          94.5       171.2    65.5  ...               152
# 2 164      front          99.8       176.6    66.2  ...               109
#   164      front          99.4       176.6    66.4  ...               136
#
# ...

# %%
df.tail(10)
# Out:
#        %symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# -1 74       volvo               gas    std      four      wagon          rwd
# -2 103      volvo               gas    std      four      sedan          rwd
# -1 74       volvo               gas    std      four      wagon          rwd
# -2 103      volvo               gas  turbo      four      sedan          rwd
# -1 74       volvo               gas  turbo      four      wagon          rwd
#    95       volvo               gas    std      four      sedan          rwd
#    95       volvo               gas  turbo      four      sedan          rwd
#    95       volvo               gas    std      four      sedan          rwd
#    95       volvo            diesel  turbo      four      sedan          rwd
#    95       volvo               gas  turbo      four      sedan          rwd
#
#        body-style  drive-wheels  wheel-base  length  ...  num-of-cylinders  \
# ...

# %%
df.describe()
# Out:
#        drive-wheels  wheel-base      length       width       height  \
# count    205.000000  205.000000  205.000000  205.000000   205.000000
# mean      98.756585  174.049268   65.907805   53.724878  2555.565854
# std        6.021776   12.337289    2.145204    2.443522   520.680204
# min       86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%       94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%       97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%      102.400000  183.100000   66.900000   55.500000  2935.000000
# max      120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        num-of-cylinders      stroke    city-mpg  highway-mpg
# count        205.000000  205.000000  205.000000   205.000000
# mean         126.907317   10.142537   25.219512    30.751220
# std           41.642693    3.972040    6.542142     6.886443
# min           61.000000    7.000000   13.000000    16.000000
# ...

# %%
df.describe(include="all")
# Out:
#        %symboling normalized-losses make fuel-type aspiration num-of-doors  \
# count         205               205  205       205        205          205
# unique         22                 2    2         3          5            3
# top        toyota               gas  std      four      sedan          fwd
# freq           32               185  168       114         96          120
# mean          NaN               NaN  NaN       NaN        NaN          NaN
# std           NaN               NaN  NaN       NaN        NaN          NaN
# min           NaN               NaN  NaN       NaN        NaN          NaN
# 25%           NaN               NaN  NaN       NaN        NaN          NaN
# 50%           NaN               NaN  NaN       NaN        NaN          NaN
# 75%           NaN               NaN  NaN       NaN        NaN          NaN
# max           NaN               NaN  NaN       NaN        NaN          NaN
#
#        body-style  drive-wheels  wheel-base      length  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 205 entries, (3, '?') to (-1, '95')
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   %symboling           205 non-null    object
#  1   normalized-losses    205 non-null    object
#  2   make                 205 non-null    object
#  3   fuel-type            205 non-null    object
#  4   aspiration           205 non-null    object
#  5   num-of-doors         205 non-null    object
#  6   body-style           205 non-null    object
#  7   drive-wheels         205 non-null    float64
#  8   wheel-base           205 non-null    float64
#  9   length               205 non-null    float64
#  10  width                205 non-null    float64
#  11  height               205 non-null    int64
#  12  curb-weight          205 non-null    object
#  13  engine-type          205 non-null    object
#  14  num-of-cylinders     205 non-null    int64
# ...

# %%
df.dtypes
# Out:
# %symboling              object
# normalized-losses       object
# make                    object
# fuel-type               object
# aspiration              object
# num-of-doors            object
# body-style              object
# drive-wheels           float64
# wheel-base             float64
# length                 float64
# width                  float64
# height                   int64
# curb-weight             object
# engine-type             object
# num-of-cylinders         int64
# engine-size             object
# fuel-system             object
# bore                    object
# stroke                 float64
# compression-ratio       object
# horsepower-peak-rpm     object
# city-mpg                 int64
# highway-mpg              int64
# price                   object
# dtype: object

# %%
df["body-style"]
# Out:
#  3  ?      front
#     ?      front
#  1  ?      front
#  2  164    front
#     164    front
#            ...
# -1  95     front
#     95     front
#     95     front
#     95     front
#     95     front
# Name: body-style, Length: 205, dtype: object

# %%
df["height"]=df["height"]+1

# %%
df["height"]
# Out:
#  3  ?      2549
#     ?      2549
#  1  ?      2824
#  2  164    2338
#     164    2825
#            ...
# -1  95     2953
#     95     3050
#     95     3013
#     95     3218
#     95     3063
# Name: height, Length: 205, dtype: int64

# %%
df.dropna(subset=["price"], axis=0, inplace=True)

# %%
mean1=df["height"].mean()

# %%
import numpy as np
df["price"].replace(np.nan, mean1)
# Out:
#  3  ?      13495
#     ?      16500
#  1  ?      16500
#  2  164    13950
#     164    17450
#            ...
# -1  95     16845
#     95     19045
#     95     21485
#     95     22470
#     95     22625
# Name: price, Length: 205, dtype: object

# %%
df["city-mpg"]=235/df["city-mpg"]

# %%
df.rename(columns={"city-mpg":"city-L/100km"},inplace=True)

# %%
df.describe()
# Out:
#        drive-wheels  wheel-base      length       width       height  \
# count    205.000000  205.000000  205.000000  205.000000   205.000000
# mean      98.756585  174.049268   65.907805   53.724878  2556.565854
# std        6.021776   12.337289    2.145204    2.443522   520.680204
# min       86.600000  141.100000   60.300000   47.800000  1489.000000
# 25%       94.500000  166.300000   64.100000   52.000000  2146.000000
# 50%       97.000000  173.200000   65.500000   54.100000  2415.000000
# 75%      102.400000  183.100000   66.900000   55.500000  2936.000000
# max      120.900000  208.100000   72.300000   59.800000  4067.000000
#
#        num-of-cylinders      stroke  city-L/100km  highway-mpg
# count        205.000000  205.000000    205.000000   205.000000
# mean         126.907317   10.142537      9.949525    30.751220
# std           41.642693    3.972040      2.573104     6.886443
# min           61.000000    7.000000      4.795918    16.000000
# ...

# %%
df.dtypes
# Out:
# %symboling              object
# normalized-losses       object
# make                    object
# fuel-type               object
# aspiration              object
# num-of-doors            object
# body-style              object
# drive-wheels           float64
# wheel-base             float64
# length                 float64
# width                  float64
# height                   int64
# curb-weight             object
# engine-type             object
# num-of-cylinders         int64
# engine-size             object
# fuel-system             object
# bore                    object
# stroke                 float64
# compression-ratio       object
# horsepower-peak-rpm     object
# city-L/100km           float64
# highway-mpg              int64
# price                   object
# dtype: object

# %%
df["length"]=df["length"]/df["length"].max()

# %%
df["length"]
# Out:
#  3  ?      0.886584
#     ?      0.886584
#  1  ?      0.905947
#  2  164    0.915629
#     164    0.918396
#              ...
# -1  95     0.952974
#     95     0.951591
#     95     0.952974
#     95     0.952974
#     95     0.952974
# Name: length, Length: 205, dtype: float64

# %%
df["length"]=df["length"]-df["length"].mean()/df["length"].std()

# %%
df["length"]
# Out:
#  3  ?     -29.836746
#     ?     -29.836746
#  1  ?     -29.817382
#  2  164   -29.807700
#     164   -29.804934
#              ...
# -1  95    -29.770356
#     95    -29.771739
#     95    -29.770356
#     95    -29.770356
#     95    -29.770356
# Name: length, Length: 205, dtype: float64

# %%
bins=np.linspace(min(df["length"]), max(df["length"]),4)

# %%
groups=["low","medium","high"]

# %%
df["binned-length"]=pd.cut(df["length"],bins,labels=groups,include_lowest=True)

# %%
pd.get_dummies(df["num-of-doors"])
# Out:
#         4wd  fwd  rwd
#  3 ?      0    0    1
#    ?      0    0    1
#  1 ?      0    0    1
#  2 164    0    1    0
#    164    1    0    0
# ...     ...  ...  ...
# -1 95     0    0    1
#    95     0    0    1
#    95     0    0    1
#    95     0    0    1
#    95     0    0    1
#
# [205 rows x 3 columns]

# %%
dwc=df["drive-wheels"].value_counts()

# %%
c=dwc.index.name='drive-wheels'

# %%
c
# Out:
# 'drive-wheels'

# %%
dwc=df["drive-wheels"].value_counts()

# %%
import seaborn as sns

# %%
sns.boxplot(x='drive-wheels', y='width', data=df)

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter('engine-size','price')
